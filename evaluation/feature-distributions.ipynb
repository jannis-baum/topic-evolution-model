# %%
import numpy as np
import pandas as pd

from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

import matplotlib.pyplot as plt
from IPython.display import display

from helpers import import_data

# %%
X, y = import_data()
print(pd.DataFrame(y).value_counts())
pd.DataFrame(X).describe()
# Out:
# 0
# Human     1818
# GPT3       687
# GPT4       344
# Gemini     310
# GPT2       286
# Name: count, dtype: int64
#             0            1            2            3            4  \
# count  3445.0  3445.000000  3445.000000  3445.000000  3445.000000
# mean      0.0     0.522790     0.720472     0.664111     7.067082
# std       0.0     0.202385     0.173823     0.175440     2.236436
# min       0.0     0.000857     0.000000     0.026316     0.500000
# 25%       0.0     0.366102     0.666667     0.529412     5.727270
# 50%       0.0     0.532710     0.769231     0.705882     6.833330
# 75%       0.0     0.691358     0.833333     0.800000     8.000000
# max       0.0     1.000000     1.000000     1.000000    32.000000
#
#                  5            6
# count  3445.000000  3445.000000
# mean      4.925007     0.238302
# std       1.958231     0.084530
# min       1.000000     0.028949
# 25%       3.835540     0.183929
# 50%       4.510200     0.224920
# ...

# %%
def plot_density(metric):
    df = pd.DataFrame({ 'metric': X[:, metric - 1] })
    df['label'] = y
    
    fig, ax = plt.subplots(figsize=(8,6))
    for label, df1 in df.groupby('label'):
        df1.metric.plot(kind="kde", ax=ax, label=label, alpha=0.9 if label == 'human' else 0.3)
    plt.legend()
    plt.title(f'Metric {i}')

# %%
for i in range(2, 8):
    plot_density(i)
